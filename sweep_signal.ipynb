# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
C1 = 4.0
C2 = 0.0187
Trec = 13.0
wmin = 0.4*2*np.pi # rad/s
wmax = 6.0*2*np.pi # rad/s
A = 0.2
t = np.linspace(0, 15, 1000) 
dt = t[1]-t[0]  
K = C2*(np.exp((C1*t)/Trec)-1)
w = wmin + K*(wmax-wmin)
theta = np.cumsum(w)*dt # integration of w(t) with respect to t
delta_sweep = A*np.sin(theta)

# %%
plt.plot(t, delta_sweep)
plt.axis([0, 12, -0.2, 0.2])
plt.show()

# %%
dt
# Out:
# np.float64(0.015015015015015015)
